# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dfWitness = pd.read_csv('random_witness.csv')
dfFunctional = pd.read_csv('random_functional.csv')

# %%
# Define the subplots
fig, ax = plt.subplots(2, 2)
# Set the size of the figure
fig.set_size_inches(10, 10)
dfWitness.hist(column='I_trMrho_e', bins=100, ax=ax[0, 0], title='Witness Number')
dfWitness.hist(column='I_sign_e', bins=100, ax=ax[1, 0], title='Witness Sign')
dfFunctional.hist(column='I_trMrho_e', bins=100, ax=ax[0, 1],title='Functional Number')
dfFunctional.hist(column='I_sign_e', bins=100, ax=ax[1, 1], title='Functional Sign')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_210595/614042977.py in <module>
#       3 # Set the size of the figure
#       4 fig.set_size_inches(10, 10)
# ----> 5 dfWitness.hist(column='I_trMrho_e', bins=100, ax=ax[0, 0], title='Witness Number')
#       6 dfWitness.hist(column='I_sign_e', bins=100, ax=ax[1, 0], title='Witness Sign')
#       7 dfFunctional.hist(column='I_trMrho_e', bins=100, ax=ax[0, 1], color='red', title='Functional Number')
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     224     """
#     225     plot_backend = _get_plot_backend(backend)
# --> 226     return plot_backend.hist_frame(
#     227         data,
#     228         column=column,
#
# ...

# %%
df.hist(column='I_sign_e', bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'I_sign_e'}>]], dtype=object)
